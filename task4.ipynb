# %% [markdown]
# <a href="https://colab.research.google.com/github/Rojashree555/Task1/blob/main/task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
data1=pd.read_csv("/content/college_1.csv")
data2=pd.read_csv("/content/college_2.csv")
frames=[data1,data2]
result = pd.concat(frames)
result
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %%
df1=pd.DataFrame(result)
present_week=df1[df1['CodeKata Score']>15000]
present_week.to_csv(' Exceeded expectations.csv', index=False)

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %%
Reached = df1[(df1['CodeKata Score'] > 10000) & (df1['CodeKata Score'] < 15000) ]
Reached.to_csv('Reached_expectations.csv',index=False)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %%
Needs = df1[(df1['CodeKata Score'] >7000) & (df1['CodeKata Score'] < 10000) ]
Needs.to_csv('Needs_Improvement.csv',index=False)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Un=df1[df1['CodeKata Score']<7000]
Un.to_csv(' Unsatisfactory.csv', index=False)

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
avg=df1.mean(axis=0)
avg
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# python                      54.352941
# mysql                       23.500000
# Previous Geekions         3842.352941
# CodeKata Score            4051.764706
# Rising                     209.411765
# python_en                   29.657143
# computational_thinking       2.200000
# dtype: float64

# %% [markdown]
# ###### No of students participated

# %%
print(len(df1.index))
# Out:
# 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
print(df1.count())
#print(sum(df1['python']))
# Out:
# Name                      119
# python                    119
# mysql                     119
# Previous Geekions         119
# CodeKata Score            119
# Department                119
# Rising                    119
# python_en                  35
# computational_thinking     35
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 119 entries, 0 to 34
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    119 non-null    object
#  1   python                  119 non-null    float64
#  2   mysql                   119 non-null    float64
#  3   Previous Geekions       119 non-null    int64
#  4   CodeKata Score          119 non-null    int64
#  5   Department              119 non-null    object
#  6   Rising                  119 non-null    int64
#  7   python_en               35 non-null     float64
#  8   computational_thinking  35 non-null     float64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 9.3+ KB

# %%
df1.isnull().sum()
# Out:
# Name                       0
# python                     0
# mysql                      0
# Previous Geekions          0
# CodeKata Score             0
# Department                 0
# Rising                     0
# python_en                 84
# computational_thinking    84
# dtype: int64

# %%
df1['Name'].value_counts()
# Out:
# A.Dharani            1
# santhosh             1
# Bodipudi Harini      1
# Ganesh Ramkumar R    1
# Chandru              1
#                     ..
# Barath D             1
# tamilarasi           1
# SOWMIYA.V            1
# SarumathiR           1
# Hariharan            1
# Name: Name, Length: 119, dtype: int64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
df1.sort_values(by='Rising',ascending=False)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 9             Balaji     -1.0   20.0               6170            8160
# 22        santhoshini    -1.0    0.0               3910            5740
# ..                ...     ...    ...                ...             ...
# 36         selvakumar   100.0    0.0               1900            1900
# 35           Barath D    74.0    4.0               1910            1910
# 34         tamilarasi   100.0  100.0               1910            1910
# 33          SOWMIYA.V    85.0    0.0               2160            2160
# 34          Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
df1.sort_values(by='Previous Geekions',ascending=False)
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 0   ASHOK KUMAR K   100.0   31.0              19400           19400
# 1         Chandru     0.0    0.0              14150           14490
# ..            ...     ...    ...                ...             ...
# 82   mohamed nabi     0.0    0.0                  0               0
# 79   KarthikeyanS    45.0    0.0                  0               0
# 80       BARATH.P    29.0    0.0                  0               0
# 81  N.Ajith kumar    82.0    0.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                 Department  Rising  python_en  \
# 0         Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df1.groupby(['Name']).sum().plot(kind='pie',y='CodeKata Score',autopct='%1.0f%%')

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df1.plot.barh(x='Department', y='CodeKata Score', figsize=(8, 8));
